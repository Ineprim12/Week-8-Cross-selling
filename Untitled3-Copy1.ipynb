# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy.stats import skew

# %%
data = pd.read_csv('C:\\Users\\Partners\\AppData\\Local\\Temp\\Temp1_Cross Selling.zip\\Cross Selling\\Test.csv')
# Out:
# C:\Users\Partners\AppData\Local\Temp\ipykernel_1864\3389111995.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('C:\\Users\\Partners\\AppData\\Local\\Temp\\Temp1_Cross Selling.zip\\Cross Selling\\Test.csv')

# %%
dict = {'fecha_dato' : 'Date',
        'ncodpers' : 'Customer code',
        'ind_empleado' : 'Employee index',
        'pais_residencia' : "Customer's Country residence",
        'sexo' : "Customer's sex",
        'age' : 'Age',
        'fecha_alta' : 'The date in which the customer became as the first holder of a contract in the bank',
        'ind_nuevo' : 'New customer Index',
        'antiguedad' : 'Customer seniority (in months)',
        'indrel' : '1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)',
        'ult_fec_cli_1t' : "Last date as primary customer",
        'indrel_1mes' : "Customer type at the beginning of the month",
        'tiprel_1mes' : "Customer relation type at the beginning of the month",
        'indresi' : "Residence index (S (Yes) or N (No) if the residence country is the same than the bank country)",
        'indext' : "Foreigner index (S (Yes) or N (No) if the customer's birth country is different than the bank country)",
        'conyuemp' : 'Spouse index. 1 if the customer is spouse of an employee',
        'canal_entrada' : 'channel used by the customer to join',
        'indfall' : 'Deceased index. N/S',
        'tipodom' : 'Addres type. 1, primary address',
        'cod_prov' : "Province code (customer's address)",
        'nomprov' : 'Province name',
        'ind_actividad_cliente' : "Activity index (1, active customer; 0, inactive customer)",
        'renta' : 'Gross income of the household',
        'segmento' : 'segmentation: 01 - VIP, 02 - Individuals 03 - college graduated',
        'ind_ahor_fin_ult1' : 'Saving Account',
        'ind_aval_fin_ult1' : 'Guarantees',
        'ind_cco_fin_ult1' : 'Current Accounts',
        'ind_cder_fin_ult1' : 'Derivada Account',
        'ind_cno_fin_ult1' : 'Payroll Account',
        'ind_ctju_fin_ult1' : 'Junior Account',
        'ind_ctma_fin_ult1' : 'Más particular Account',
        'ind_ctop_fin_ult1' : 'particular Account',
        'ind_ctpp_fin_ult1' : 'particular Plus Account',
        'ind_deco_fin_ult1' : 'Short-term deposits',
        'ind_deme_fin_ult1' : 'Medium-term deposits',
        'ind_dela_fin_ult1' : 'Long-term deposits',
        'ind_ecue_fin_ult1' : 'e-account',
        'ind_fond_fin_ult1' : 'Funds',
        'ind_hip_fin_ult1' : 'Mortgage',
        'ind_plan_fin_ult1' : 'Pensions',
        'ind_pres_fin_ult1' : 'Loans',
        'ind_reca_fin_ult1' : 'Taxes',
        'ind_tjcr_fin_ult1' : 'Credit Card',
        'ind_valo_fin_ult1' : 'Securities',
        'ind_viv_fin_ult1' : 'Home Account',
        'ind_nomina_ult1' : 'Payroll',
        'ind_nom_pens_ult1' : 'Pensions',
        'ind_recibo_ult1' : 'Direct Debit'   
       }

data1 = data.rename(columns = dict)

# %%
data1.shape
# Out:
# (929615, 24)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 929615 entries, 0 to 929614
# Data columns (total 24 columns):
#  #   Column                                                                                                                                       Non-Null Count   Dtype
# ---  ------                                                                                                                                       --------------   -----
#  0   The table is partitioned for this column                                                                                                     929615 non-null  object
#  1   Customer code                                                                                                                                929615 non-null  int64
#  2   Employee index: A active, B ex employed, F filial, N not employee, P pasive                                                                  929615 non-null  object
#  3   Customer's Country residence                                                                                                                 929615 non-null  object
#  4   Customer's sex                                                                                                                               929610 non-null  object
#  5   Age                                                                                                                                          929615 non-null  int64
#  6   The date in which the customer became as the first holder of a contract in the bank                                                          929615 non-null  object
#  7   New customer Index. 1 if the customer registered in the last 6 months.                                                                       929615 non-null  int64
#  8   Customer seniority (in months)                                                                                                               929615 non-null  int64
#  9   1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)                                                    929615 non-null  int64
#  10  Last date as primary customer (if he isn't at the end of the month)                                                                          1683 non-null    object
#  11  Customer type at the beginning of the month ,1 (First/Primary customer), 2 (co-owner ),P (Potential),3 (former primary), 4(former co-owner)  929592 non-null  float64
#  12  Customer relation type at the beginning of the month, A (active), I (inactive), P (former customer),R (Potential)                            929592 non-null  object
#  13  Residence index (S (Yes) or N (No) if the residence country is the same than the bank country)                                               929615 non-null  object
#  14  Foreigner index (S (Yes) or N (No) if the customer's birth country is different than the bank country)                                       929615 non-null  object
#  15  Spouse index. 1 if the customer is spouse of an employee                                                                                     104 non-null     object
#  16  channel used by the customer to join                                                                                                         927534 non-null  object
#  17  Deceased index. N/S                                                                                                                          929615 non-null  object
#  18  Addres type. 1, primary address                                                                                                              929615 non-null  int64
#  19  Province code (customer's address)                                                                                                           925619 non-null  float64
#  20  Province name                                                                                                                                925619 non-null  object
#  21  Activity index (1, active customer; 0, inactive customer)                                                                                    929615 non-null  int64
#  22  Gross income of the household                                                                                                                929615 non-null  object
#  23  segmentation: 01 - VIP, 02 - Individuals 03 - college graduated                                                                              927367 non-null  object
# dtypes: float64(2), int64(7), object(15)
# memory usage: 170.2+ MB

# %%
print("Object Columns: ", data1.select_dtypes(include = ["object"]).columns)
# Out:
# Object Columns:  Index(['The table is partitioned for this column',
#        'Employee index: A active, B ex employed, F filial, N not employee, P pasive',
#        'Customer's Country residence', 'Customer's sex',
#        'The date in which the customer became as the first holder of a contract in the bank',
#        'Last date as primary customer (if he isn't at the end of the month)',
#        'Customer relation type at the beginning of the month, A (active), I (inactive), P (former customer),R (Potential)',
#        'Residence index (S (Yes) or N (No) if the residence country is the same than the bank country)',
#        'Foreigner index (S (Yes) or N (No) if the customer's birth country is different than the bank country)',
#        'Spouse index. 1 if the customer is spouse of an employee',
#        'channel used by the customer to join', 'Deceased index. N/S',
#        'Province name', 'Gross income of the household',
#        'segmentation: 01 - VIP, 02 - Individuals 03 - college graduated'],
#       dtype='object')

# %%
print("Numerical Columns: ", data1.select_dtypes(include = ["int64"]).columns)
# Out:
# Numerical Columns:  Index(['Customer code', 'Age',
#        'New customer Index. 1 if the customer registered in the last 6 months.',
#        'Customer seniority (in months)',
#        '1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)',
#        'Addres type. 1, primary address',
#        'Activity index (1, active customer; 0, inactive customer)'],
#       dtype='object')

# %%
data1=data1.drop_duplicates()
data1
# Out:
#        The table is partitioned for this column  Customer code  \
# 0                                    2016-06-28          15889
# 1                                    2016-06-28        1170544
# 2                                    2016-06-28        1170545
# 3                                    2016-06-28        1170547
# 4                                    2016-06-28        1170548
# ...                                         ...            ...
# 929610                               2016-06-28         660237
# 929611                               2016-06-28         660238
# 929612                               2016-06-28         660240
# 929613                               2016-06-28         660243
# 929614                               2016-06-28         660248
#
#        Employee index: A active, B ex employed, F filial, N not employee, P pasive  \
# 0                                                       F
# 1                                                       N
# 2                                                       N
# 3                                                       N
# 4                                                       N
# ...                                                   ...
# 929610                                                  N
# 929611                                                  N
# 929612                                                  N
# 929613                                                  N
# 929614                                                  N
#
#        Customer's Country residence Customer's sex  Age  \
# 0                                ES              V   56
# 1                                ES              H   36
# 2                                ES              V   22
# 3                                ES              H   22
# 4                                ES              H   22
# ...                             ...            ...  ...
# 929610                           ES              V   55
# 929611                           ES              V   30
# 929612                           ES              V   52
# 929613                           ES              V   32
# 929614                           ES              V   92
#
#        The date in which the customer became as the first holder of a contract in the bank  \
# 0                                              1995-01-16
# 1                                              2013-08-28
# 2                                              2013-08-28
# 3                                              2013-08-28
# 4                                              2013-08-28
# ...                                                   ...
# 929610                                         1999-04-21
# 929611                                         2006-11-29
# 929612                                         2006-11-29
# 929613                                         2006-11-29
# 929614                                         2006-11-29
#
#         New customer Index. 1 if the customer registered in the last 6 months.  \
# 0                                                       0
# 1                                                       0
# 2                                                       0
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 929610                                                  0
# 929611                                                  0
# 929612                                                  0
# 929613                                                  0
# 929614                                                  0
#
#         Customer seniority (in months)  \
# 0                                  256
# 1                                   34
# 2                                   34
# 3                                   34
# 4                                   34
# ...                                ...
# 929610                             206
# 929611                             115
# 929612                             115
# 929613                             115
# 929614                             115
#
#         1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)  \
# 0                                                       1
# 1                                                       1
# 2                                                       1
# 3                                                       1
# 4                                                       1
# ...                                                   ...
# 929610                                                  1
# 929611                                                  1
# 929612                                                  1
# 929613                                                  1
# 929614                                                  1
#
#         ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
# ...     ...
# 929610  ...
# 929611  ...
# 929612  ...
# 929613  ...
# 929614  ...
#
#        Foreigner index (S (Yes) or N (No) if the customer's birth country is different than the bank country)  \
# 0                                                       N
# 1                                                       N
# 2                                                       N
# 3                                                       N
# 4                                                       N
# ...                                                   ...
# 929610                                                  N
# 929611                                                  N
# 929612                                                  N
# 929613                                                  N
# 929614                                                  N
#
#         Spouse index. 1 if the customer is spouse of an employee  \
# 0                                                       N
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 929610                                                NaN
# 929611                                                NaN
# 929612                                                NaN
# 929613                                                NaN
# 929614                                                NaN
#
#        channel used by the customer to join Deceased index. N/S  \
# 0                                       KAT                   N
# 1                                       KAT                   N
# 2                                       KHE                   N
# 3                                       KHE                   N
# 4                                       KHE                   N
# ...                                     ...                 ...
# 929610                                  KAT                   N
# 929611                                  KFC                   N
# 929612                                  KBZ                   N
# 929613                                  KFC                   N
# 929614                                  KAT                   N
#
#        Addres type. 1, primary address Province code (customer's address)  \
# 0                                    1                               28.0
# 1                                    1                                3.0
# 2                                    1                               15.0
# 3                                    1                                8.0
# 4                                    1                                7.0
# ...                                ...                                ...
# 929610                               1                               28.0
# 929611                               1                               26.0
# 929612                               1                               33.0
# 929613                               1                               33.0
# 929614                               1                               45.0
#
#          Province name  \
# 0               MADRID
# 1             ALICANTE
# 2            CORUÑA, A
# 3            BARCELONA
# 4       BALEARS, ILLES
# ...                ...
# 929610          MADRID
# 929611       RIOJA, LA
# 929612        ASTURIAS
# 929613        ASTURIAS
# 929614          TOLEDO
#
#        Activity index (1, active customer; 0, inactive customer)  \
# 0                                                       1
# 1                                                       0
# 2                                                       1
# 3                                                       0
# 4                                                       0
# ...                                                   ...
# 929610                                                  1
# 929611                                                  0
# 929612                                                  1
# 929613                                                  0
# 929614                                                  0
#
#         Gross income of the household  \
# 0                           326124.90
# 1                                  NA
# 2                                  NA
# 3                           148402.98
# 4                           106885.80
# ...                               ...
# 929610                      128643.57
# 929611                             NA
# 929612                       72765.27
# 929613                      147488.88
# 929614                             NA
#
#         segmentation: 01 - VIP, 02 - Individuals 03 - college graduated
# 0                                                01 - TOP
# 1                                       02 - PARTICULARES
# 2                                      03 - UNIVERSITARIO
# 3                                      03 - UNIVERSITARIO
# 4                                      03 - UNIVERSITARIO
# ...                                                   ...
# 929610                                           01 - TOP
# 929611                                  02 - PARTICULARES
# 929612                                  02 - PARTICULARES
# 929613                                  02 - PARTICULARES
# 929614                                  02 - PARTICULARES
#
# [929615 rows x 24 columns]

# %%
df = data.select_dtypes([int, float])

fig=plt.figure(figsize=(10,10))
for i ,columns in enumerate (df,1):
    ax= plt.subplot(5,3,i)
    sns.boxplot(data= df , x=df[columns])
    ax.set_xlabel(None)
    ax.set_title(f'Distribution of {columns}')
    plt.tight_layout(w_pad=3)
plt.show()

# %%
data1.skew(axis=0, skipna=True)
# Out:
# C:\Users\Partners\AppData\Local\Temp\ipykernel_1864\1867141580.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data1.skew(axis=0, skipna=True)
# Customer code                                                                                                                                   -0.327419
# Age                                                                                                                                              0.830373
# New customer Index. 1 if the customer registered in the last 6 months.                                                                           5.739031
# Customer seniority (in months)                                                                                                                -555.491690
# 1 (First/Primary), 99 (Primary customer during the month but not at the end of the month)                                                       23.438419
# Customer type at the beginning of the month ,1 (First/Primary customer), 2 (co-owner ),P (Potential),3 (former primary), 4(former co-owner)    185.543646
# Addres type. 1, primary address                                                                                                                  0.000000
# Province code (customer's address)                                                                                                              -0.124568
# Activity index (1, active customer; 0, inactive customer)                                                                                        0.302309
# dtype: float64
